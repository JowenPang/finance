# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('combined_data.csv')
pd.set_option('max_columns',None)
pd.set_option('max_rows',None)

# %%
df['VALUE DATE']=pd.to_datetime(df['VALUE DATE'])
df['MATURITY DATE']=pd.to_datetime(df['MATURITY DATE'])
df['ISSUE DATE']=pd.to_datetime(df['ISSUE DATE'])

# %%
code = df['STOCK CODE'].unique()
code = code.tolist()
code
# Out:
# ['DI140013',
#  'DJ140003',
#  'DJ140039',
#  'DK140037',
#  'DK140038',
#  'DL140035',
#  'DL140036',
#  'DM140033',
#  'DM140034',
#  'DN100015',
#  'DN140031',
#  'DN140032',
#  'DO140029',
#  'DO140030',
#  'DP080045',
#  'DP140005',
#  'DP140028',
#  'DQ080044',
#  'DQ140004',
#  'DQ140027',
#  'DR052766',
#  'DR080043',
#  'DR140025',
#  'DR140026',
#  'DS052767',
#  'DS140023',
#  'DS140024',
#  'DT140021',
#  'DT140022',
#  'DU140011',
#  'DU140012',
#  'DV140009',
#  'DV140010',
#  'DW140007',
#  'DW140008',
#  'DW190007',
#  'DX140006',
#  'DX190008',
#  'DZ012851',
#  'DZ021250',
#  'PI140054',
#  'PI140058',
#  'PI150010',
#  'PJ130058',
#  'PJ140034',
#  'PJ140053',
#  'PK130057',
#  'PK140035',
#  'PK140052',
#  'PK170005',
#  'PK170006',
#  'PK170007',
#  'PK170008',
#  'PL120012',
#  'PL120033',
#  'PL120034',
#  'PL130056',
#  'PL140036',
#  'PL140051',
#  'PL150011',
#  'PM100046',
#  'PM110032',
#  'PM120011',
#  'PM120031',
#  'PM120032',
#  'PM130055',
#  'PM140037',
#  'PM140050',
#  'PN100047',
#  'PN110033',
#  'PN120010',
#  'PN120029',
#  'PN120030',
#  'PN130054',
#  'PN140038',
#  'PN140049',
#  'PN150019',
#  'PN170026',
#  'PN180002',
#  'PN190015',
#  'PO100048',
#  'PO110034',
#  'PO120009',
#  'PO120027',
#  'PO120028',
#  'PO130053',
#  'PO140039',
#  'PO140048',
#  'PO180006',
#  'PP100049',
#  'PP110035',
#  'PP120008',
#  'PP120025',
#  'PP120026',
#  'PP130052',
#  'PP140040',
#  'PP150012',
#  'PQ100050',
#  'PQ110036',
#  'PQ120007',
#  'PQ120023',
#  'PQ120024',
#  'PQ130051',
#  'PR100051',
#  'PR110037',
#  'PR120006',
#  'PR120021',
#  'PR120022',
#  'PR130050',
#  'PS100052',
#  'PS110038',
#  'PS120005',
#  'PS120019',
#  'PS120020',
#  'PS130060',
#  'PT110039',
#  'PT120017',
#  'PT120018',
#  'PU110040',
#  'PW160005',
#  'PY130067',
#  'PZ100010',
#  'PZ140059',
#  'PZ140060',
#  'PZ150002',
#  'PZ150006',
#  'PZ150009',
#  'PZ150014',
#  'PZ160007',
#  'PZ160016',
#  'PZ180009',
#  'PZ190007',
#  'UE190219',
#  'UF180003',
#  'UG170114',
#  'UG180004',
#  'UG180173',
#  'UG200113',
#  'UG200180',
#  'UH160157',
#  'UH160158',
#  'UH180005',
#  'UI140168',
#  'UI150042',
#  'UI150076',
#  'UI180006',
#  'UI180163',
#  'UI200090',
#  'UJ180007',
#  'UJ180024',
#  'UK140147',
#  'UK140167',
#  'UK160159',
#  'UK170029',
#  'UK170144',
#  'UK180008',
#  'UK190257',
#  'UL180009',
#  'UM180010',
#  'UN120032',
#  'UN130032',
#  'UN130048',
#  'UN140148',
#  'UN160125',
#  'UN180011',
#  'UN180078',
#  'UN180162',
#  'UN190218',
#  'UN190259',
#  'UN200150',
#  'UO150029',
#  'UO190260',
#  'UP150030',
#  'UP190261',
#  'UQ150031',
#  'UQ190262',
#  'UR190263',
#  'US130057',
#  'US190226',
#  'US190264',
#  'UX160124',
#  'UZ170177',
#  'UZ190051',
#  'VE180327',
#  'VE180328',
#  'VE190114',
#  'VE190222',
#  'VE190261',
#  'VE190266',
#  'VE190267',
#  'VE200062',
#  'VE200066',
#  'VE200072',
#  'VE200079',
#  'VE200082',
#  'VE200090',
#  'VE200125',
#  'VE200126',
#  'VE200148',
#  'VE200222',
#  'VE200230',
#  'VE200258',
#  'VE200277',
#  'VF170230',
#  'VF180049',
#  'VF180177',
#  'VF190171',
#  'VF190259',
#  'VF190260',
#  'VF190264',
#  'VF190265',
#  'VF200127',
#  'VF200231',
#  'VF200257',
#  'VG160241',
#  'VG160283',
#  'VG160292',
#  'VG160329',
#  'VG170002',
#  'VG170167',
#  'VG170170',
#  'VG170181',
#  'VG170187',
#  'VG170222',
#  'VG170229',
#  'VG170283',
#  'VG170322',
#  'VG170386',
#  'VG170392',
#  'VG170397',
#  'VG170404',
#  'VG180050',
#  'VG180085',
#  'VG180096',
#  'VG180176',
#  'VG180203',
#  'VG180238',
#  'VG180272',
#  'VG180300',
#  'VG180305',
#  'VG180363',
#  'VG190002',
#  'VG190014',
#  'VG190020',
#  'VG190030',
#  'VG190033',
#  'VG190077',
#  'VG190097',
#  'VG190104',
#  'VG190111',
#  'VG190116',
#  'VG190170',
#  'VG190185',
#  'VG190193',
#  'VG190221',
#  'VG190257',
#  'VG190258',
#  'VG190262',
#  'VG190263',
#  'VG190268',
#  'VG190288',
#  'VG190289',
#  'VG190344',
#  'VG200001',
#  'VG200002',
#  'VG200067',
#  'VG200083',
#  'VG200086',
#  'VG200087',
#  'VG200107',
#  'VG200124',
#  'VG200128',
#  'VG200169',
#  'VG200194',
#  'VG200217',
#  'VG200232',
#  'VG200256',
#  'VG200272',
#  'VG200281',
#  'VH150197',
#  'VH160240',
#  'VH160284',
#  'VH170156',
#  'VH170188',
#  'VH170221',
#  'VH170239',
#  'VH170393',
#  'VH180002',
#  'VH180051',
#  'VH180175',
#  'VH180339',
#  'VH190021',
#  'VH190095',
#  'VH190149',
#  'VH190194',
#  'VH190343',
#  'VH200018',
#  'VH200129',
#  'VH200233',
#  'VH200255',
#  'VH200273',
#  'VH200282',
#  'VI140205',
#  'VI140209',
#  'VI140220',
#  'VI140343',
#  'VI140368',
#  'VI140411',
#  'VI150028',
#  'VI150052',
#  'VI150054',
#  'VI150069',
#  'VI150160',
#  'VI150196',
#  'VI150261',
#  'VI150273',
#  'VI160019',
#  'VI160026',
#  'VI160110',
#  'VI160132',
#  'VI160176',
#  'VI160219',
#  'VI160252',
#  'VI160285',
#  'VI160293',
#  'VI160327',
#  'VI160431',
#  'VI160447',
#  'VI170124',
#  'VI170141',
#  'VI170151',
#  'VI170155',
#  'VI170157',
#  'VI170168',
#  'VI170180',
#  'VI170189',
#  'VI170220',
#  'VI170242',
#  'VI170256',
#  'VI170323',
#  'VI170341',
#  'VI170342',
#  'VI170382',
#  'VI170384',
#  'VI170391',
#  'VI170394',
#  'VI180003',
#  'VI180004',
#  'VI180052',
#  'VI180087',
#  'VI180097',
#  'VI180137',
#  'VI180174',
#  'VI180185',
#  'VI180186',
#  'VI180239',
#  'VI180248',
#  'VI180259',
#  'VI180273',
#  'VI180275',
#  'VI180294',
#  'VI180301',
#  'VI180304',
#  'VI180334',
#  'VI180362',
#  'VI180369',
#  'VI180370',
#  'VI190022',
#  'VI190034',
#  'VI190058',
#  'VI190060',
#  'VI190100',
#  'VI190119',
#  'VI190150',
#  'VI190195',
#  'VI190212',
#  'VI190220',
#  'VI190229',
#  'VI190287',
#  'VI200010',
#  'VI200068',
#  'VI200084',
#  'VI200095',
#  'VI200108',
#  'VI200130',
#  'VI200173',
#  'VI200182',
#  'VI200183',
#  'VI200186',
#  'VI200215',
#  'VI200218',
#  'VI200234',
#  'VI200254',
#  'VI200283',
#  'VJ130289',
#  'VJ130296',
#  'VJ130383',
#  'VJ140096',
#  'VJ140344',
#  'VJ140412',
#  'VJ140413',
#  'VJ150150',
#  'VJ150195',
#  'VJ150284',
#  'VJ150285',
#  'VJ160058',
#  'VJ160133',
#  'VJ160251',
#  'VJ160286',
#  'VJ160428',
#  'VJ170190',
#  'VJ170219',
#  'VJ170343',
#  'VJ170344',
#  'VJ180005',
#  'VJ180006',
#  'VJ180053',
#  'VJ180173',
#  'VJ190151',
#  'VJ190196',
#  'VJ200131',
#  'VJ200235',
#  'VJ200253',
#  'VJ200284',
#  'VK120295',
#  'VK120318',
#  'VK120331',
#  'VK120382',
#  'VK120388',
#  'VK130025',
#  'VK130044',
#  'VK130057',
#  'VK130093',
#  'VK130153',
#  'VK130164',
#  'VK130165',
#  'VK130202',
#  'VK130245',
#  'VK130288',
#  'VK130297',
#  'VK130328',
#  'VK130386',
#  'VK140094',
#  'VK140095',
#  'VK140108',
#  'VK140143',
#  'VK140166',
#  'VK140345',
#  'VK140352',
#  'VK140353',
#  'VK140367',
#  'VK140414',
#  'VK150053',
#  'VK150063',
#  'VK150070',
#  'VK150133',
#  'VK150137',
#  'VK150151',
#  'VK150194',
#  'VK150210',
#  'VK150286',
#  'VK150287',
#  'VK160112',
#  'VK160134',
#  'VK160146',
#  'VK160159',
#  'VK160175',
#  'VK160250',
#  'VK160294',
#  'VK170142',
#  'VK170191',
#  'VK170218',
#  'VK170233',
#  'VK170243',
#  'VK170257',
#  'VK170345',
#  'VK170346',
#  'VK170390',
#  'VK180001',
#  'VK180007',
#  'VK180008',
#  'VK180054',
#  'VK180075',
#  'VK180098',
#  'VK180172',
#  'VK180303',
#  'VK190031',
#  'VK190035',
#  'VK190089',
#  'VK190101',
#  'VK190120',
#  'VK190152',
#  'VK190183',
#  'VK190197',
#  'VK190213',
#  'VK190219',
#  'VK190230',
#  'VK190235',
#  'VK190282',
#  'VK190286',
#  'VK190314',
#  'VK200069',
#  'VK200071',
#  'VK200085',
#  'VK200091',
#  'VK200094',
#  'VK200132',
#  'VK200170',
#  'VK200181',
#  'VK200206',
#  'VK200216',
#  'VK200236',
#  'VK200252',
#  'VK200285',
#  'VL110425',
#  'VL110444',
#  'VL120007',
#  'VL120063',
#  'VL120296',
#  'VL120319',
#  'VL120332',
#  'VL130026',
#  'VL130027',
#  'VL130042',
#  'VL130043',
#  'VL130058',
#  'VL130166',
#  'VL130167',
#  'VL130190',
#  'VL130203',
#  'VL130287',
#  'VL130298',
#  'VL140093',
#  'VL140150',
#  'VL140346',
#  'VL140351',
#  'VL140405',
#  'VL140406',
#  'VL150127',
#  'VL150152',
#  'VL150209',
#  'VL150288',
#  'VL150289',
#  'VL160059',
#  'VL160145',
#  'VL160249',
#  'VL160255',
#  'VL160317',
#  'VL170166',
#  'VL170192',
#  'VL170217',
#  'VL170240',
#  'VL170347',
#  'VL170348',
#  'VL180009',
#  'VL180010',
#  'VL180055',
#  'VL180149',
#  'VL180171',
#  'VL190153',
#  'VL190198',
#  'VL190281',
#  'VL200092',
#  'VL200133',
#  'VL200237',
#  'VL200251',
#  'VL200286',
#  'VM110102',
#  'VM110205',
#  'VM110426',
#  'VM110445',
#  'VM120008',
#  'VM120064',
#  'VM120297',
#  'VM120321',
#  'VM120333',
#  'VM120384',
#  'VM120389',
#  'VM130028',
#  'VM130029',
#  'VM130040',
#  'VM130041',
#  'VM130059',
#  'VM130168',
#  'VM130169',
#  'VM130189',
#  'VM130204',
#  'VM130286',
#  'VM130299',
#  'VM130384',
#  'VM140092',
#  'VM140347',
#  'VM140350',
#  'VM140398',
#  'VM140407',
#  'VM150153',
#  'VM150208',
#  'VM150290',
#  'VM150291',
#  'VM160060',
#  'VM160135',
#  'VM160248',
#  'VM160256',
#  'VM170165',
#  'VM170193',
#  'VM170216',
#  'VM170258',
#  'VM170349',
#  'VM170350',
#  'VM180011',
#  'VM180012',
#  'VM180056',
#  'VM180170',
#  'VM190154',
#  'VM190199',
#  'VM200134',
#  'VM200238',
#  'VM200268',
#  'VN090912',
#  'VN100268',
#  'VN100298',
#  'VN110029',
#  'VN110050',
#  'VN110103',
#  'VN110206',
#  'VN110216',
#  'VN110219',
#  'VN110356',
#  'VN110401',
#  'VN110420',
#  'VN110427',
#  'VN110446',
#  'VN110485',
#  'VN120009',
#  'VN120027',
#  'VN120071',
#  'VN120176',
#  'VN120191',
#  'VN120219',
#  'VN120281',
#  'VN120286',
#  'VN120298',
#  'VN120322',
#  'VN120334',
#  'VN120337',
#  'VN120390',
#  'VN120455',
#  'VN130030',
#  'VN130031',
#  'VN130038',
#  'VN130039',
#  'VN130060',
#  'VN130094',
#  'VN130121',
#  'VN130152',
#  'VN130170',
#  'VN130171',
#  'VN130174',
#  'VN130188',
#  'VN130205',
#  'VN130233',
#  'VN130246',
#  'VN130285',
#  'VN130300',
#  'VN130387',
#  'VN140053',
#  'VN140091',
#  'VN140109',
#  'VN140144',
#  'VN140164',
#  'VN140167',
#  'VN140171',
#  'VN140335',
#  'VN140399',
#  'VN140400',
#  'VN140415',
#  'VN140416',
#  'VN140424',
#  'VN150062',
#  'VN150064',
#  'VN150071',
#  'VN150157',
#  'VN150159',
#  'VN150207',
#  'VN150260',
#  'VN150272',
#  'VN150292',
#  'VN150293',
#  'VN160022',
#  'VN160032',
#  'VN160111',
#  'VN160136',
#  'VN160177',
#  'VN160247',
#  'VN160257',
#  'VN160271',
#  'VN160295',
#  'VN160328',
#  'VN170143',
#  'VN170152',
#  'VN170154',
#  'VN170194',
#  'VN170215',
#  'VN170241',
#  'VN170244',
#  'VN170245',
#  'VN170259',
#  'VN170351',
#  'VN170352',
#  'VN170395',
#  'VN180013',
#  'VN180014',
#  'VN180057',
#  'VN180095',
#  'VN180099',
#  'VN180169',
#  'VN180190',
#  'VN180242',
#  'VN180276',
#  'VN180302',
#  'VN180337',
#  'VN180371',
#  'VN190036',
#  'VN190085',
#  'VN190091',
#  'VN190102',
#  'VN190155',
#  'VN190184',
#  'VN190188',
#  'VN190200',
#  'VN190214',
#  'VN190218',
#  'VN190231',
#  'VN190236',
#  'VN190285',
#  'VN190315',
#  'VN200070',
#  'VN200089',
#  'VN200093',
#  'VN200096',
#  'VN200135',
#  'VN200163',
#  'VN200171',
#  'VN200178',
#  'VN200180',
#  'VN200184',
#  'VN200207',
#  'VN200239',
#  'VN200267',
#  'VO110051',
#  'VO110207',
#  'VO110428',
#  'VO110447',
#  'VO120010',
#  'VO120299',
#  'VO120323',
#  'VO130032',
#  'VO130037',
#  'VO130061',
#  'VO130172',
#  'VO130206',
#  'VO130252',
#  'VO130301',
#  'VO140401',
#  'VO140417',
#  'VO150206',
#  'VO150294',
#  'VO150295',
#  'VO160137',
#  'VO160246',
#  'VO160258',
#  'VO170195',
#  'VO170214',
#  'VO170353',
#  'VO170354',
#  'VO180015',
#  'VO180016',
#  'VO180058',
#  'VO180168',
#  'VO180372',
#  'VO180373',
#  'VO190092',
#  'VO190156',
#  'VO190201',
#  'VO200136',
#  'VO200240',
#  'VO200266',
#  'VP070896',
#  'VP080396',
#  'VP080766',
#  'VP100408',
#  'VP110030',
#  'VP110052',
#  'VP110402',
#  'VP110429',
#  'VP110448',
#  'VP120011',
#  'VP120177',
#  'VP120265',
#  'VP120266',
#  'VP120267',
#  'VP120268',
#  'VP120282',
#  'VP120300',
#  'VP120324',
#  'VP120457',
#  'VP130062',
#  'VP130095',
#  'VP130115',
#  'VP130207',
#  'VP130251',
#  'VP130302',
#  'VP140145',
#  'VP140404',
#  'VP140418',
#  'VP150072',
#  'VP150205',
#  'VP150259',
#  'VP150296',
#  'VP150297',
#  'VP160138',
#  'VP160259',
#  'VP170196',
#  'VP170213',
#  'VP170355',
#  'VP170356',
#  'VP180017',
#  'VP180018',
#  'VP180059',
#  'VP180167',
#  'VP180374',
#  'VP180375',
#  'VP190093',
#  'VP190157',
#  'VP190202',
#  'VP190217',
#  'VP190316',
#  'VP200137',
#  'VP200241',
#  'VP200265',
#  'VQ061773',
#  'VQ062353',
#  'VQ070343',
#  'VQ070344',
#  'VQ070897',
#  'VQ070898',
#  'VQ080387',
#  'VQ080397',
#  'VQ080767',
#  'VQ080768',
#  'VQ110053',
#  'VQ110430',
#  'VQ110449',
#  'VQ120012',
#  'VQ120301',
#  'VQ120325',
#  'VQ130063',
#  'VQ130116',
#  'VQ130187',
#  'VQ130208',
#  'VQ130250',
#  'VQ130303',
#  'VQ140160',
#  'VQ150204',
#  'VQ150298',
#  'VQ150299',
#  'VQ160139',
#  'VQ160245',
#  'VQ160260',
#  'VQ170197',
#  'VQ170212',
#  'VQ170357',
#  'VQ170358',
#  'VQ180019',
#  'VQ180020',
#  'VQ180060',
#  'VQ180166',
#  'VQ180376',
#  'VQ180377',
#  'VQ190158',
#  'VQ190203',
#  'VQ200138',
#  'VQ200242',
#  'VQ200264',
#  'VR060697',
#  'VR060698',
#  'VR060855',
#  'VR061774',
#  'VR061775',
#  'VR062348',
#  'VR062354',
#  'VR062355',
#  'VR070345',
#  'VR070346',
#  'VR070899',
#  'VR070900',
#  'VR080388',
#  'VR080398',
#  'VR080769',
#  'VR080770',
#  'VR110054',
#  'VR110431',
#  'VR110450',
#  'VR120013',
#  'VR120302',
#  'VR120328',
#  'VR130064',
#  'VR130117',
#  'VR130186',
#  'VR130249',
#  'VR130304',
#  'VR140161',
#  'VR140162',
#  'VR150203',
#  'VR150300',
#  'VR150301',
#  'VR160140',
#  'VR160244',
#  'VR160261',
#  'VR170198',
#  'VR170211',
#  'VR170359',
#  'VR170360',
#  'VR180021',
#  'VR180022',
#  'VR180061',
#  'VR180165',
#  'VR180378',
#  'VR180379',
#  'VR190159',
#  'VR190204',
#  'VR200139',
#  'VR200243',
#  'VR200263',
#  'VS050521',
#  'VS060699',
#  'VS060854',
#  'VS061776',
#  'VS061777',
#  'VS062350',
#  'VS062351',
#  'VS062356',
#  'VS062357',
#  'VS070347',
#  'VS070348',
#  'VS070901',
#  'VS070902',
#  'VS080389',
#  'VS080399',
#  'VS080771',
#  'VS080772',
#  'VS110031',
#  'VS110055',
#  'VS110215',
#  'VS110403',
#  'VS110432',
#  'VS110451',
#  'VS120014',
#  'VS120026',
#  'VS120178',
#  'VS120283',
#  'VS120303',
#  'VS120327',
#  'VS130065',
#  'VS130096',
#  'VS130118',
#  'VS130185',
#  'VS130248',
#  'VS130305',
#  'VS130351',
#  'VS140056',
#  'VS140146',
#  'VS140163',
#  'VS140170',
#  'VS150002',
#  'VS150073',
#  'VS150202',
#  'VS150302',
#  'VS150303',
#  'VS160109',
#  'VS160141',
#  'VS160243',
#  'VS160262',
#  'VS170003',
#  'VS170199',
#  'VS170210',
#  'VS170227',
#  'VS170367',
#  'VS170368',
#  'VS170389',
#  'VS180023',
#  'VS180024',
#  'VS180037',
#  'VS180062',
#  'VS180164',
#  'VS180251',
#  'VS180336',
#  'VS180380',
#  'VS190032',
#  'VS190160',
#  ...]

# %% [markdown]
# ## Insert the STOCK CODE

# %%
df_v = df[df['STOCK CODE']=='PI140058']
df_v
# Out:
#     STOCK CODE                                 STOCK NAME_x VALUE DATE  \
# 561   PI140058  SABAH STATE 4.275% 09.12.2019 - Issue No. 1 2019-08-01
# 562   PI140058  SABAH STATE 4.275% 09.12.2019 - Issue No. 1 2019-09-03
# 563   PI140058  SABAH STATE 4.275% 09.12.2019 - Issue No. 1 2019-10-01
# 564   PI140058  SABAH STATE 4.275% 09.12.2019 - Issue No. 1 2019-11-01
#
#      EVAL MID YIELD  EVAL MID PRICE  MODIFIED DURATION  CONVEXITY  \
# 561           3.482         100.270              0.350      0.246
# 562           3.408         100.218              0.262      0.137
# 563           3.376         100.159              0.186      0.070
# 564           3.388         100.085              0.102      0.021
#
#      COMPOSITE LIQUIDITY SCORE (T-1)        BOND TYPE RATING ISSUE DATE  \
# 561                              1.3  Fixed Rate Bond    AAA 2014-12-09
# 562                              1.3  Fixed Rate Bond    AAA 2014-12-09
# 563                              0.0  Fixed Rate Bond    AAA 2014-12-09
# 564                              0.0  Fixed Rate Bond    AAA 2014-12-09
#
#     MATURITY DATE  COUPON FREQUENCY  NEXT COUPON RATE  \
# 561    2019-12-09               2.0             4.275
# 562    2019-12-09               2.0             4.275
# 563    2019-12-09               2.0             4.275
# 564    2019-12-09               2.0             4.275
#
#      FACILITY AMOUNT/FACILITY LIMIT(MYR MIL)  \
# 561                                     1000
# 562                                     1000
# 563                                     1000
# 564                                     1000
#
#      FACILITY OUTSTANDING AMOUNT(MYR MIL)  BOND ISSUE AMOUNT(MYR MIL)  \
# 561                                  1000                        1000
# 562                                  1000                        1000
# 563                                  1000                        1000
# 564                                  1000                        1000
#
#     REMAINING TENURE  BOND CURRENT OUTSTANDING AMOUNT(MYR MIL)  \
# 561               6M                                      1000
# 562               3M                                      1000
# 563               3M                                      1000
# 564               3M                                      1000
#
#      ISSUER FACILITY LIMIT(MYR MIL)  ISSUER OUTSTANDING AMOUNT(MYR MIL)  \
# 561                            1544                                1000
# 562                            1544                                1000
# 563                            1544                                1000
# 564                            1544                                1000
#
#              SECTOR  CALLABLE/PUTTABLE
# 561  PUBLIC FINANCE                  0
# 562  PUBLIC FINANCE                  0
# 563  PUBLIC FINANCE                  0
# 564  PUBLIC FINANCE                  0

# %% [markdown]
# ### Bond Price over time

# %%
plt.plot(df_v['VALUE DATE'],df_v['EVAL MID PRICE']);
plt.xlabel('Value Date');
plt.ylabel('Price');

# %% [markdown]
# ### YTM over time

# %%
plt.plot(df_v['VALUE DATE'],df_v['EVAL MID YIELD']);
plt.xlabel('Value Date');
plt.ylabel('Yield')
# Out:
# Text(0, 0.5, 'Yield')
