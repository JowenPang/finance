# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data0906.csv')

# %%
df.shape
# Out:
# (13753, 12)

# %%
df.head(30)
# Out:
#    VALUE DATE STOCK CODE  EVAL MID YIELD  COMPOSITE LIQUIDITY SCORE (T-1)  \
# 0    1/8/2019   DJ140003           3.772                              0.0
# 1    1/9/2019   DJ140003           3.650                              0.0
# 2   1/10/2019   DJ140003           3.587                              0.0
# 3   1/11/2019   DJ140003           3.599                              0.0
# 4   1/12/2019   DJ140003           3.571                              0.0
# 5    1/1/2020   DJ140003           3.526                              0.0
# 6    1/2/2020   DJ140003           3.375                              3.0
# 7    1/3/2020   DJ140003           3.179                              2.7
# 8    1/4/2020   DJ140003           3.237                              2.7
# 9    1/5/2020   DJ140003           3.079                              2.3
# 10   1/6/2020   DJ140003           2.814                              2.3
# 11   1/7/2020   DJ140003           2.826                              2.3
# ...

# %%
df['VALUE DATE']= pd.to_datetime(df['VALUE DATE'],format='%d/%m/%Y')

# %%
df_opr = pd.read_excel('OPR rate.xlsx')

# %%
df_opr
# Out:
#          Date  OPR level
# 0  2019-08-01       3.00
# 1  2019-09-01       3.00
# 2  2019-10-01       3.00
# 3  2019-11-01       3.00
# 4  2019-12-01       3.00
# 5  2020-01-01       2.75
# 6  2020-02-01       2.75
# 7  2020-03-01       2.75
# 8  2020-04-01       2.50
# 9  2020-05-01       2.50
# 10 2020-06-01       2.00
# 11 2020-07-01       2.00
# 12 2020-08-01       1.75
# 13 2020-09-01       1.75
# 14 2020-10-01       1.75
# 15 2020-11-01       1.75
# 16 2020-12-01       1.75

# %%
df_opr['VALUE DATE']= pd.to_datetime(df_opr['Date'],format='%d/%m/%Y')
df_opr.drop('Date',axis=1,inplace=True)

# %%
df_opr
# Out:
#     OPR level VALUE DATE
# 0        3.00 2019-08-01
# 1        3.00 2019-09-01
# 2        3.00 2019-10-01
# 3        3.00 2019-11-01
# 4        3.00 2019-12-01
# 5        2.75 2020-01-01
# 6        2.75 2020-02-01
# 7        2.75 2020-03-01
# 8        2.50 2020-04-01
# 9        2.50 2020-05-01
# 10       2.00 2020-06-01
# 11       2.00 2020-07-01
# 12       1.75 2020-08-01
# 13       1.75 2020-09-01
# 14       1.75 2020-10-01
# 15       1.75 2020-11-01
# 16       1.75 2020-12-01

# %%
df = df.merge(df_opr,on='VALUE DATE')

# %%
df.shape
# Out:
# (13753, 13)

# %%
df.head(30)
# Out:
#    VALUE DATE STOCK CODE  EVAL MID YIELD  COMPOSITE LIQUIDITY SCORE (T-1)  \
# 0  2019-08-01   DJ140003           3.772                              0.0
# 1  2019-08-01   DJ140039           3.685                              0.0
# 2  2019-08-01   DK140037           3.857                              0.0
# 3  2019-08-01   DK140038           3.817                              0.0
# 4  2019-08-01   DL140035           3.924                              0.0
# 5  2019-08-01   DL140036           3.899                              2.7
# 6  2019-08-01   DM140033           3.964                              0.0
# 7  2019-08-01   DM140034           3.949                              0.0
# 8  2019-08-01   DN100015           3.625                              2.7
# 9  2019-08-01   DN140031           3.993                              0.0
# 10 2019-08-01   DN140032           3.980                              0.0
# 11 2019-08-01   DO140029           4.048                              0.0
# ...

# %%
df.sort_values(['STOCK CODE','VALUE DATE'])
# Out:
#       VALUE DATE STOCK CODE  EVAL MID YIELD  COMPOSITE LIQUIDITY SCORE (T-1)  \
# 0     2019-08-01   DJ140003           3.772                              0.0
# 874   2019-09-01   DJ140003           3.650                              0.0
# 1766  2019-10-01   DJ140003           3.587                              0.0
# 2663  2019-11-01   DJ140003           3.599                              0.0
# 3594  2019-12-01   DJ140003           3.571                              0.0
# ...          ...        ...             ...                              ...
# 10180 2020-06-01   VZ180148           4.361                              3.7
# 11093 2020-07-01   VZ180148           4.357                              3.7
# 11988 2020-08-01   VZ180148           4.267                              3.3
# 12876 2020-09-01   VZ180148           4.234                              2.7
# 13752 2020-10-01   VZ180148           4.197                              2.3
#
# ...

# %%
df[df['VALUE DATE']<'7/1/2020'].head(20)
# Out:
#    VALUE DATE STOCK CODE  EVAL MID YIELD  COMPOSITE LIQUIDITY SCORE (T-1)  \
# 0  2019-08-01   DJ140003           3.772                              0.0
# 1  2019-08-01   DJ140039           3.685                              0.0
# 2  2019-08-01   DK140037           3.857                              0.0
# 3  2019-08-01   DK140038           3.817                              0.0
# 4  2019-08-01   DL140035           3.924                              0.0
# 5  2019-08-01   DL140036           3.899                              2.7
# 6  2019-08-01   DM140033           3.964                              0.0
# 7  2019-08-01   DM140034           3.949                              0.0
# 8  2019-08-01   DN100015           3.625                              2.7
# 9  2019-08-01   DN140031           3.993                              0.0
# 10 2019-08-01   DN140032           3.980                              0.0
# 11 2019-08-01   DO140029           4.048                              0.0
# ...

# %%
train_set = df[df['VALUE DATE']<'7/1/2020']

# %%
test_set = df[df['VALUE DATE']>='7/1/2020']

# %%
train_set.shape,test_set.shape
# Out:
# ((10181, 13), (3572, 13))

# %%
train_y = train_set['OUTPUT PRICE']

# %%
train_X = train_set.drop(['OUTPUT PRICE'],axis=1)

# %%
train_X.shape
# Out:
# (10181, 12)

# %%
test_y = test_set['OUTPUT PRICE']

# %%
test_X = test_set.drop(['OUTPUT PRICE'],axis=1)

# %%
train_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10181 entries, 0 to 10180
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   VALUE DATE                       10181 non-null  datetime64[ns]
#  1   STOCK CODE                       10181 non-null  object
#  2   EVAL MID YIELD                   10181 non-null  float64
#  3   COMPOSITE LIQUIDITY SCORE (T-1)  10181 non-null  float64
#  4   COUPON FREQUENCY                 10181 non-null  int64
#  5   NEXT COUPON RATE                 10181 non-null  float64
#  6   CALLABLE/PUTTABLE                10181 non-null  int64
#  7   MODIFIED DURATION                10181 non-null  float64
#  8   EVAL MID PRICE                   10181 non-null  float64
#  9   REMAINING TENURE                 10181 non-null  int64
#  10  RATING TARGET                    10181 non-null  float64
# ...
